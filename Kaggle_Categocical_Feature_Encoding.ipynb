# %% [markdown]
# https://www.kaggle.com/competitions/cat-in-the-dat

# %%
import glob
import os

import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #read_data

# %%
path = '/content/drive/MyDrive/data/cat-in-the-dat'
print(os.listdir(path))
files = glob.glob(path + '/*.csv')

for file in files:
    if 'test' in file:
        test = pd.read_csv(file)
    elif 'train' in file:
        train = pd.read_csv(file)
    elif 'sample' in file:
        sub = pd.read_csv(file)

test.shape, train.shape, sub.shape
# Out:
# ['test.csv', 'train.csv', 'sample_submission.csv']
# ((200000, 24), (300000, 25), (200000, 2))

# %%
train.set_index('id',inplace=True)
test.set_index('id',inplace=True)

# %%
a = train.columns.to_series().groupby(train.dtypes).groups
for i,v in a.items():
    print(i,v)
# Out:
# int64 Index(['bin_0', 'bin_1', 'bin_2', 'ord_0', 'day', 'month', 'target'], dtype='object')
# object Index(['bin_3', 'bin_4', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5',
#        'nom_6', 'nom_7', 'nom_8', 'nom_9', 'ord_1', 'ord_2', 'ord_3', 'ord_4',
#        'ord_5'],
#       dtype='object')

# %%
df = train.copy()

# %%
df
# Out:
#         bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# id
# 0           0      0      0     T     Y  Green   Triangle    Snake
# 1           0      1      0     T     Y  Green  Trapezoid  Hamster
# 2           0      0      0     F     Y   Blue  Trapezoid     Lion
# 3           0      1      0     F     Y    Red  Trapezoid    Snake
# 4           0      0      0     F     N    Red  Trapezoid     Lion
# ...       ...    ...    ...   ...   ...    ...        ...      ...
# 299995      0      0      0     T     N    Red  Trapezoid    Snake
# 299996      0      0      0     F     Y  Green  Trapezoid     Lion
# 299997      0      0      0     F     Y   Blue       Star  Axolotl
# 299998      0      1      0     F     Y  Green     Square  Axolotl
# 299999      0      0      0     F     Y   Blue  Trapezoid      Dog
#
#              nom_3     nom_4  ...      nom_9 ord_0        ord_1        ord_2  \
# id                            ...
# ...

# %%
df.dtypes.sort_values()
# Out:
# bin_0      int64
# day        int64
# ord_0      int64
# month      int64
# target     int64
# bin_1      int64
# bin_2      int64
# nom_0     object
# ord_5     object
# ord_4     object
# ord_3     object
# ord_2     object
# ord_1     object
# bin_4     object
# nom_9     object
# nom_7     object
# bin_3     object
# nom_5     object
# nom_4     object
# nom_3     object
# nom_2     object
# nom_1     object
# nom_8     object
# nom_6     object
# dtype: object

# %%
def resumetable(df):
    print(df.shape)
    summary = pd.DataFrame(df.dtypes, columns=['데이터타입']) #.sort_values()
    summary = summary.reset_index()
    summary = summary.rename(columns = {'index':'피처'})
    summary['결측치 개수'] = df.isnull().sum().values
    summary['고윳값 개수'] = df.nunique().values
    summary['첫 번째 값'] = df.loc[0].values
    summary['두 번째 값'] = df.loc[1].values
    summary['세 번째 값'] = df.loc[2].values


    return summary

# %%
resumetable(df)
# Out:
# (300000, 24)
#         피처   데이터타입  결측치 개수  고윳값 개수       첫 번째 값       두 번째 값     세 번째 값
# 0    bin_0   int64       0       2            0            0          0
# 1    bin_1   int64       0       2            0            1          0
# 2    bin_2   int64       0       2            0            0          0
# 3    bin_3  object       0       2            T            T          F
# 4    bin_4  object       0       2            Y            Y          Y
# 5    nom_0  object       0       3        Green        Green       Blue
# 6    nom_1  object       0       6     Triangle    Trapezoid  Trapezoid
# 7    nom_2  object       0       6        Snake      Hamster       Lion
# 8    nom_3  object       0       6      Finland       Russia     Russia
# 9    nom_4  object       0       4      Bassoon        Piano   Theremin
# 10   nom_5  object       0     222    50f116bcf    b3b4d25d0  3263bdce5
# 11   nom_6  object       0     522    3ac1b8814    fbcb50fc1  0922e3cb8
# ...
